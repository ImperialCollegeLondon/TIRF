# %%
from nd2reader import ND2Reader
import matplotlib.pyplot as plt

with ND2Reader('c:/users/omer/tirf/data/set1/100xdiluted_10T_200msdelay_1_bsa_500ms.nd2') as images:
    plt.imshow(images[1])
    print(len(images))
# Out:
# 30
