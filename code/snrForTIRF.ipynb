# %%
import numpy as np
from TIRFConstants import *
import matplotlib.pyplot as plt
import scipy.stats as stats
import math

def gaussian(mu, sigma, x):  
    return np.exp((-1/2)*((x - mu)**2)/ (sigma**2)) * (1/(sigma * math.sqrt(2*np.pi))) 
mu = 0
sigma = 1.5
fig, ax = plt.subplots()
x = np.linspace(-3,3,100)
#ax.plot(x + 3 , gaussian(mu, sigma, x))

x = np.linspace(-3*sigma, 3*sigma, 100)
for w in WAVELENGTHS: 
    ax.plot(x + w, gaussian(w, sigma, x + w))
plt.show()
